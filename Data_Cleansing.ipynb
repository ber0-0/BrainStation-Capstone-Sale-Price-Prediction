# %% [markdown]
# # Data Preparation

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

pd.options.display.max_columns = None
pd.options.display.max_rows = None

# %%
dt = pd.read_csv("data/train.csv")
print(dt.shape)
dt.head()
# Out:
# (1460, 81)
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 0         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 1         Lvl    AllPub       FR2       Gtl      Veenker      Feedr
# 2         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 3         Lvl    AllPub    Corner       Gtl      Crawfor       Norm
# 4         Lvl    AllPub       FR2       Gtl      NoRidge       Norm
#
#   Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# ...

# %%
test = pd.read_csv("data/test.csv")
print(test.shape)
test.head()
# Out:
# (1459, 80)
#      Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0  1461          20       RH         80.0    11622   Pave   NaN      Reg
# 1  1462          20       RL         81.0    14267   Pave   NaN      IR1
# 2  1463          60       RL         74.0    13830   Pave   NaN      IR1
# 3  1464          60       RL         78.0     9978   Pave   NaN      IR1
# 4  1465         120       RL         43.0     5005   Pave   NaN      IR1
#
#   LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 0         Lvl    AllPub    Inside       Gtl        NAmes      Feedr
# 1         Lvl    AllPub    Corner       Gtl        NAmes       Norm
# 2         Lvl    AllPub    Inside       Gtl      Gilbert       Norm
# 3         Lvl    AllPub    Inside       Gtl      Gilbert       Norm
# 4         HLS    AllPub    Inside       Gtl      StoneBr       Norm
#
#   Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# ...

# %%
dt.columns
# Out:
# Index(['Id', 'MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street',
#        'Alley', 'LotShape', 'LandContour', 'Utilities', 'LotConfig',
#        'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType',
#        'HouseStyle', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd',
#        'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType',
#        'MasVnrArea', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual',
#        'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1',
#        'BsmtFinType2', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating',
#        'HeatingQC', 'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF',
#        'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
#        'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual',
#        'TotRmsAbvGrd', 'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType',
#        'GarageYrBlt', 'GarageFinish', 'GarageCars', 'GarageArea', 'GarageQual',
# ...

# %%
train_X = dt.iloc[:,:-1]
train_X.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 0         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 1         Lvl    AllPub       FR2       Gtl      Veenker      Feedr
# 2         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 3         Lvl    AllPub    Corner       Gtl      Crawfor       Norm
# 4         Lvl    AllPub       FR2       Gtl      NoRidge       Norm
#
#   Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# ...

# %%
train_y = dt["SalePrice"]
train_y.head()
# Out:
# 0    208500
# 1    181500
# 2    223500
# 3    140000
# 4    250000
# Name: SalePrice, dtype: int64

# %%
dt.dtypes
# Out:
# Id                 int64
# MSSubClass         int64
# MSZoning          object
# LotFrontage      float64
# LotArea            int64
# Street            object
# Alley             object
# LotShape          object
# LandContour       object
# Utilities         object
# LotConfig         object
# LandSlope         object
# Neighborhood      object
# Condition1        object
# Condition2        object
# BldgType          object
# HouseStyle        object
# OverallQual        int64
# OverallCond        int64
# YearBuilt          int64
# YearRemodAdd       int64
# RoofStyle         object
# RoofMatl          object
# Exterior1st       object
# Exterior2nd       object
# MasVnrType        object
# MasVnrArea       float64
# ExterQual         object
# ExterCond         object
# Foundation        object
# BsmtQual          object
# BsmtCond          object
# BsmtExposure      object
# BsmtFinType1      object
# BsmtFinSF1         int64
# BsmtFinType2      object
# BsmtFinSF2         int64
# ...

# %% [markdown]
# ---
#
# ## Handle Missing Values

# %%
dt.columns[dt.isnull().sum()>0]
# Out:
# Index(['LotFrontage', 'Alley', 'MasVnrType', 'MasVnrArea', 'BsmtQual',
#        'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinType2',
#        'Electrical', 'FireplaceQu', 'GarageType', 'GarageYrBlt',
#        'GarageFinish', 'GarageQual', 'GarageCond', 'PoolQC', 'Fence',
#        'MiscFeature'],
#       dtype='object')

# %%
dt['Alley'].fillna("No_Access", inplace=True)
dt['MasVnrType'].fillna("None", inplace=True)
dt['BsmtQual'].fillna("No_Basement", inplace=True)
dt['BsmtCond'].fillna("No_Basement", inplace=True)
dt['BsmtExposure'].fillna("No_Basement", inplace=True)
dt['BsmtFinType1'].fillna("No_Basement", inplace=True)
dt['BsmtFinType2'].fillna("No_Basement", inplace=True)
dt['FireplaceQu'].fillna("No_Fireplace", inplace=True)
dt['GarageType'].fillna("No_Garage", inplace=True)
dt['GarageFinish'].fillna("No_Garage", inplace=True)
dt['GarageQual'].fillna("No_Garage", inplace=True)
dt['GarageCond'].fillna("No_Garage", inplace=True)
dt['PoolQC'].fillna("No_Pool", inplace=True)
dt['Fence'].fillna("No_Fence", inplace=True)
dt['MiscFeature'].fillna("None", inplace=True)

# %%
dt.columns[dt.isnull().sum()>0]
# Out:
# Index(['LotFrontage', 'MasVnrArea', 'Electrical', 'GarageYrBlt'], dtype='object')

# %%
dt.loc[:,['LotFrontage', 'MasVnrArea', 'Electrical', 'GarageYrBlt']].isnull().sum()
# Out:
# LotFrontage    259
# MasVnrArea       8
# Electrical       1
# GarageYrBlt     81
# dtype: int64

# %%
dt[dt['LotFrontage'].isna()==True].head()
# Out:
#     Id  MSSubClass MSZoning  LotFrontage  LotArea Street      Alley LotShape  \
# 7    8          60       RL          NaN    10382   Pave  No_Access      IR1
# 12  13          20       RL          NaN    12968   Pave  No_Access      IR2
# 14  15          20       RL          NaN    10920   Pave  No_Access      IR1
# 16  17          20       RL          NaN    11241   Pave  No_Access      IR1
# 24  25          20       RL          NaN     8246   Pave  No_Access      IR1
#
#    LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 7          Lvl    AllPub    Corner       Gtl       NWAmes       PosN
# 12         Lvl    AllPub    Inside       Gtl       Sawyer       Norm
# 14         Lvl    AllPub    Corner       Gtl        NAmes       Norm
# 16         Lvl    AllPub   CulDSac       Gtl        NAmes       Norm
# 24         Lvl    AllPub    Inside       Gtl       Sawyer       Norm
#
#    Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# ...

# %%
dt['LotFrontage'].dtypes
# Out:
# dtype('float64')

# %%
dt['LotFrontage'].fillna(0, inplace=True)
dt['LotFrontage'].isna().sum()
# Out:
# 0

# %%
dt[dt['MasVnrArea'].isna()==True]
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street      Alley  \
# 234    235          60       RL          0.0     7851   Pave  No_Access
# 529    530          20       RL          0.0    32668   Pave  No_Access
# 650    651          60       FV         65.0     8125   Pave  No_Access
# 936    937          20       RL         67.0    10083   Pave  No_Access
# 973    974          20       FV         95.0    11639   Pave  No_Access
# 977    978         120       FV         35.0     4274   Pave       Pave
# 1243  1244          20       RL        107.0    13891   Pave  No_Access
# 1278  1279          60       RL         75.0     9473   Pave  No_Access
#
#      LotShape LandContour Utilities LotConfig LandSlope Neighborhood  \
# 234       Reg         Lvl    AllPub    Inside       Gtl      Gilbert
# 529       IR1         Lvl    AllPub   CulDSac       Gtl      Crawfor
# 650       Reg         Lvl    AllPub    Inside       Gtl      Somerst
# ...

# %%
dt['MasVnrArea'].fillna(0.00, inplace=True)

# %%
dt['MasVnrArea'].isna().sum()
# Out:
# 0

# %%
dt[dt['Electrical'].isna()==True]
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street      Alley  \
# 1379  1380          80       RL         73.0     9735   Pave  No_Access
#
#      LotShape LandContour Utilities LotConfig LandSlope Neighborhood  \
# 1379      Reg         Lvl    AllPub    Inside       Gtl       Timber
#
#      Condition1 Condition2 BldgType HouseStyle  OverallQual  OverallCond  \
# 1379       Norm       Norm     1Fam       SLvl            5            5
#
#       YearBuilt  YearRemodAdd RoofStyle RoofMatl Exterior1st Exterior2nd  \
# 1379       2006          2007     Gable  CompShg     VinylSd     VinylSd
#
#      MasVnrType  MasVnrArea ExterQual ExterCond Foundation BsmtQual BsmtCond  \
# 1379       None         0.0        TA        TA      PConc       Gd       TA
#
#      BsmtExposure BsmtFinType1  BsmtFinSF1 BsmtFinType2  BsmtFinSF2  \
# 1379           No          Unf           0          Unf           0
#
#       BsmtUnfSF  TotalBsmtSF Heating HeatingQC CentralAir Electrical  \
# ...

# %%
elec = dt.groupby('MSSubClass')['Electrical'].value_counts()

ax = elec.plot(kind='bar', figsize=(10,6), color="indigo", fontsize=13);
ax.set_alpha(0.8)
plt.show()

# %%
dt['Electrical'].fillna("SBrkr", inplace=True)
dt[dt['Id']==1380]
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street      Alley  \
# 1379  1380          80       RL         73.0     9735   Pave  No_Access
#
#      LotShape LandContour Utilities LotConfig LandSlope Neighborhood  \
# 1379      Reg         Lvl    AllPub    Inside       Gtl       Timber
#
#      Condition1 Condition2 BldgType HouseStyle  OverallQual  OverallCond  \
# 1379       Norm       Norm     1Fam       SLvl            5            5
#
#       YearBuilt  YearRemodAdd RoofStyle RoofMatl Exterior1st Exterior2nd  \
# 1379       2006          2007     Gable  CompShg     VinylSd     VinylSd
#
#      MasVnrType  MasVnrArea ExterQual ExterCond Foundation BsmtQual BsmtCond  \
# 1379       None         0.0        TA        TA      PConc       Gd       TA
#
#      BsmtExposure BsmtFinType1  BsmtFinSF1 BsmtFinType2  BsmtFinSF2  \
# 1379           No          Unf           0          Unf           0
#
#       BsmtUnfSF  TotalBsmtSF Heating HeatingQC CentralAir Electrical  \
# ...

# %%
dt[dt['GarageYrBlt'].isna()==True].head()
# Out:
#     Id  MSSubClass MSZoning  LotFrontage  LotArea Street      Alley LotShape  \
# 39  40          90       RL         65.0     6040   Pave  No_Access      Reg
# 48  49         190       RM         33.0     4456   Pave  No_Access      Reg
# 78  79          90       RL         72.0    10778   Pave  No_Access      Reg
# 88  89          50  C (all)        105.0     8470   Pave  No_Access      IR1
# 89  90          20       RL         60.0     8070   Pave  No_Access      Reg
#
#    LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 39         Lvl    AllPub    Inside       Gtl      Edwards       Norm
# 48         Lvl    AllPub    Inside       Gtl      OldTown       Norm
# 78         Lvl    AllPub    Inside       Gtl       Sawyer       Norm
# 88         Lvl    AllPub    Corner       Gtl       IDOTRR      Feedr
# 89         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
#
#    Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# ...

# %%
print((dt['GarageType']=="No_Garage").sum())
print(dt['GarageYrBlt'].isna().sum())
# Out:
# 81
# 81

# %% [markdown]
# ---
#
# ## EDA by plots

# %%
plt.figure(figsize=(16,16))
sns.heatmap(dt.corr())
plt.show()

# %%
dt.corr()['SalePrice'].sort_values(ascending=False)
# Out:
# SalePrice        1.000000
# OverallQual      0.790982
# GrLivArea        0.708624
# GarageCars       0.640409
# GarageArea       0.623431
# TotalBsmtSF      0.613581
# 1stFlrSF         0.605852
# FullBath         0.560664
# TotRmsAbvGrd     0.533723
# YearBuilt        0.522897
# YearRemodAdd     0.507101
# GarageYrBlt      0.486362
# MasVnrArea       0.472614
# Fireplaces       0.466929
# BsmtFinSF1       0.386420
# WoodDeckSF       0.324413
# 2ndFlrSF         0.319334
# OpenPorchSF      0.315856
# HalfBath         0.284108
# LotArea          0.263843
# BsmtFullBath     0.227122
# BsmtUnfSF        0.214479
# LotFrontage      0.209624
# BedroomAbvGr     0.168213
# ScreenPorch      0.111447
# PoolArea         0.092404
# MoSold           0.046432
# 3SsnPorch        0.044584
# BsmtFinSF2      -0.011378
# BsmtHalfBath    -0.016844
# MiscVal         -0.021190
# Id              -0.021917
# LowQualFinSF    -0.025606
# YrSold          -0.028923
# OverallCond     -0.077856
# ...

# %%
high_corr = dt.corr()['SalePrice'].sort_values(ascending=False)[:11].index

# %%
sns.pairplot(dt[high_corr])

# %%
object_dt = list(dt.select_dtypes(include='object').columns)
object_dt

# %%
dummy = pd.get_dummies(dt[object_dt], dummy_na=True)
dummy.head()
